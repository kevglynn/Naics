# %%
# %load https://raw.githubusercontent.com/codeforamerica/naics-api/master/data/scrape-examples-xrefs/scrape-naics.py
#!/usr/bin/env python

from re import compile
from csv import DictReader
from urllib import urlopen, urlencode
from bs4 import BeautifulSoup
from sys import stderr, argv
from json import dump

def find_description(soup):
    '''
    '''
    el = soup.find('h3')

    if not el:
        # Nothing.
        return

    # The description comes after the last h3, so we need to find the last one:
    while el.name == 'h3':
        # Go to next element if another h3 is encountered
        next_el = el.findNext('h3')
        if next_el:
            el = next_el
        else:
            break

    # For top-level 2-digit codes, the first line of the description is a "Sector as a Whole" subtitle in bold.
    subtitle = el.findNextSibling('b')
    if subtitle:
        el = subtitle
        yield el.string
        el = el.nextSibling.nextSibling  # Skip <br>'s after this

    el = el.nextSibling # The description isn't contained in an element, so must get next sibling.

    while True:

        if el.name is not None:
            # Expected plain text here.
            return

        text = el

        # Include text of "see other" links
        link = el.findNextSibling('a')
        if link:
            text += link.string
            link = link.nextSibling
            if link.name is None:
                text += link.string

        if text.strip():
            # Make sure string is not empty
            yield unicode(text.strip())

        for i in range(2):
            # There are supposed to be two breaks after each block of text
            el = el.nextSibling

            if not el:
                # Nothing. End of NAICS entry.
                return

            if el.name != 'br':
                # Not a break, stop.
                break

        if el.name == 'br':
            # This should be last <br>, next sibling should be text
            el = el.nextSibling

        # Stop when you hit Cross-references or Illustrative examples
        if "Illustrative Examples:" in el:
            return

        if "Cross-References." in el:
            return


def find_description_code(soup):
    '''
    '''
    el = soup.find(text=compile(r'See industry description for'))

    if not el:
        # Nothing.
        return

    el = el.nextSibling

    if not el:
        # Some 2007 codes do not actually link the number (we will have to manually get these?)
        yield unicode('[link problem]')
        return

    if el.name != 'a':
        # Expected a link
        return

    el = el.string

    yield unicode(el)


def find_examples(soup):
    ''' Generate a list of examples from a starting point.
    '''
    el = soup.find(text='Illustrative Examples:')
    
    if not el:
        # Nothing.
        return
    
    for i in range(2):
        el = el.nextSibling
        
        if el.name != 'br':
            # There are supposed to be two breaks after "Illustrative Examples"
            return
    
    while True:
        el = el.nextSibling
    
        if el.name is not None:
            # Expected plain text here.
            return
        
        if el.strip():
            # Make sure string is not empty
            yield unicode(el.strip())

        el = el.nextSibling
    
        if el.name != 'br':
            # Expected a break here
            return

def find_crossreferences(soup):
    '''
    '''
    el = soup.find(text=compile(r'^\s*Cross-References.'))
    # Whitespace at beginning of string is present in 2007 codes.

    if not el:
        # Nothing.
        return
    
    el = el.findNext('ul')
    
    if not el:
        # Expected an unordered list after some blank lines.
        return
    
    for el in el.find_all('li'):
        code, text = None, ''
    
        for el in el.contents:
            if el.name == 'a':
                text += el.string
                code = el.string
            else:
                text += unicode(el)
        
        yield dict(code=code, text=text)

try:
    outfile = argv[1]
    results = {}
except IndexError:
    print >> stderr, 'Usage: %s <output file name>' % argv[0]
    exit(1)

#rows = list(DictReader(urlopen('http://forever.codeforamerica.org.s3.amazonaws.com/NAICS/2-digit_2012_Codes.csv')))
rows = list(DictReader(urlopen('https://gist.github.com/louh/6479528/raw/9ce661a10f14d3b9c29c34e70d50d61e791a3618/naics07.csv')))

for (index, row) in enumerate(rows):

#    code = row['2012 NAICS US   Code']
    code = row['2007 NAICS US Code']

#    print >> stderr, index + 1, 'of', len(rows), '-', code, '-', row['2012 NAICS US Title']
    print >> stderr, index + 1, 'of', len(rows), '-', code, '-', row['2007 NAICS US Title']

#    q = dict(code=code, search='2012 NAICS Search')
    q = dict(code=code, search='2007 NAICS Search')
    url = 'http://www.census.gov/cgi-bin/sssd/naics/naicsrch?' + urlencode(q)
    html = urlopen(url).read()
    soup = BeautifulSoup(html)
    soup = soup.find(id='middle-column').find(class_='inside')
    
    results[code] = dict(description=[], description_code='', examples=[], crossrefs=[])
    
    for description in find_description(soup):
        results[code]['description'].append(description)
    
    for description_code in find_description_code(soup):
        results[code]['description_code'] = description_code

    for example in find_examples(soup):
        results[code]['examples'].append(example)
    
    for crossref in find_crossreferences(soup):
        results[code]['crossrefs'].append(crossref)

with open(outfile, 'w') as out:
    dump(results, out, indent=2)
# Out:
# 1 of 2328 - 11 - Agriculture, Forestry, Fishing and Hunting
# 2 of 2328 - 111 - Crop Production
# 3 of 2328 - 1111 - Oilseed and Grain Farming
# 4 of 2328 - 11111 - Soybean Farming
# 5 of 2328 - 111110 - Soybean Farming
# 6 of 2328 - 11112 - Oilseed (except Soybean) Farming
# 7 of 2328 - 111120 - Oilseed (except Soybean) Farming
# 8 of 2328 - 11113 - Dry Pea and Bean Farming
# 9 of 2328 - 111130 - Dry Pea and Bean Farming
# 10 of 2328 - 11114 - Wheat Farming
# 11 of 2328 - 111140 - Wheat Farming
# 12 of 2328 - 11115 - Corn Farming
# 13 of 2328 - 111150 - Corn Farming
# 14 of 2328 - 11116 - Rice Farming
# 15 of 2328 - 111160 - Rice Farming
# 16 of 2328 - 11119 - Other Grain Farming
# 17 of 2328 - 111191 - Oilseed and Grain Combination Farming
# 18 of 2328 - 111199 - All Other Grain Farming
# 19 of 2328 - 1112 - Vegetable and Melon Farming
# 20 of 2328 - 11121 - Vegetable and Melon Farming
# 21 of 2328 - 111211 - Potato Farming
# 22 of 2328 - 111219 - Other Vegetable (except Potato) and Melon Farming
# 23 of 2328 - 1113 - Fruit and Tree Nut Farming
# 24 of 2328 - 11131 - Orange Groves
# 25 of 2328 - 111310 - Orange Groves
# 26 of 2328 - 11132 - Citrus (except Orange) Groves
# 27 of 2328 - 111320 - Citrus (except Orange) Groves
# 28 of 2328 - 11133 - Noncitrus Fruit and Tree Nut Farming
# 29 of 2328 - 111331 - Apple Orchards
# 30 of 2328 - 111332 - Grape Vineyards
# 31 of 2328 - 111333 - Strawberry Farming
# 32 of 2328 - 111334 - Berry (except Strawberry) Farming
# 33 of 2328 - 111335 - Tree Nut Farming
# 34 of 2328 - 111336 - Fruit and Tree Nut Combination Farming
# 35 of 2328 - 111339 - Other Noncitrus Fruit Farming
# 36 of 2328 - 1114 - Greenhouse, Nursery, and Floriculture Production
# 37 of 2328 - 11141 - Food Crops Grown Under Cover
# 38 of 2328 - 111411 - Mushroom Production
# 39 of 2328 - 111419 - Other Food Crops Grown Under Cover
# 40 of 2328 - 11142 - Nursery and Floriculture Production
# 41 of 2328 - 111421 - Nursery and Tree Production
# 42 of 2328 - 111422 - Floriculture Production
# 43 of 2328 - 1119 - Other Crop Farming
# 44 of 2328 - 11191 - Tobacco Farming
# 45 of 2328 - 111910 - Tobacco Farming
# 46 of 2328 - 11192 - Cotton Farming
# 47 of 2328 - 111920 - Cotton Farming
# 48 of 2328 - 11193 - Sugarcane Farming
# 49 of 2328 - 111930 - Sugarcane Farming
# 50 of 2328 - 11194 - Hay Farming
# 51 of 2328 - 111940 - Hay Farming
# 52 of 2328 - 11199 - All Other Crop Farming
# 53 of 2328 - 111991 - Sugar Beet Farming
# 54 of 2328 - 111992 - Peanut Farming
# 55 of 2328 - 111998 - All Other Miscellaneous Crop Farming
# 56 of 2328 - 112 - Animal Production
# 57 of 2328 - 1121 - Cattle Ranching and Farming
# 58 of 2328 - 11211 - Beef Cattle Ranching and Farming, including Feedlots
# 59 of 2328 - 112111 - Beef Cattle Ranching and Farming
# 60 of 2328 - 112112 - Cattle Feedlots
# 61 of 2328 - 11212 - Dairy Cattle and Milk Production
# 62 of 2328 - 112120 - Dairy Cattle and Milk Production
# 63 of 2328 - 11213 - Dual-Purpose Cattle Ranching and Farming
# 64 of 2328 - 112130 - Dual-Purpose Cattle Ranching and Farming
# 65 of 2328 - 1122 - Hog and Pig Farming
# 66 of 2328 - 11221 - Hog and Pig Farming
# 67 of 2328 - 112210 - Hog and Pig Farming
# 68 of 2328 - 1123 - Poultry and Egg Production
# 69 of 2328 - 11231 - Chicken Egg Production
# 70 of 2328 - 112310 - Chicken Egg Production
# 71 of 2328 - 11232 - Broilers and Other Meat Type Chicken Production
# 72 of 2328 - 112320 - Broilers and Other Meat Type Chicken Production
# 73 of 2328 - 11233 - Turkey Production
# 74 of 2328 - 112330 - Turkey Production
# 75 of 2328 - 11234 - Poultry Hatcheries
# 76 of 2328 - 112340 - Poultry Hatcheries
# 77 of 2328 - 11239 - Other Poultry Production
# 78 of 2328 - 112390 - Other Poultry Production
# 79 of 2328 - 1124 - Sheep and Goat Farming
# 80 of 2328 - 11241 - Sheep Farming
# 81 of 2328 - 112410 - Sheep Farming
# 82 of 2328 - 11242 - Goat Farming
# 83 of 2328 - 112420 - Goat Farming
# 84 of 2328 - 1125 - Aquaculture
# 85 of 2328 - 11251 - Aquaculture
# 86 of 2328 - 112511 - Finfish Farming and Fish Hatcheries
# 87 of 2328 - 112512 - Shellfish Farming
# 88 of 2328 - 112519 - Other Aquaculture
# 89 of 2328 - 1129 - Other Animal Production
# 90 of 2328 - 11291 - Apiculture
# 91 of 2328 - 112910 - Apiculture
# 92 of 2328 - 11292 - Horses and Other Equine Production
# 93 of 2328 - 112920 - Horses and Other Equine Production
# 94 of 2328 - 11293 - Fur-Bearing Animal and Rabbit Production
# 95 of 2328 - 112930 - Fur-Bearing Animal and Rabbit Production
# 96 of 2328 - 11299 - All Other Animal Production
# 97 of 2328 - 112990 - All Other Animal Production
# 98 of 2328 - 113 - Forestry and Logging
# 99 of 2328 - 1131 - Timber Tract Operations
# 100 of 2328 - 11311 - Timber Tract Operations
# 101 of 2328 - 113110 - Timber Tract Operations
# 102 of 2328 - 1132 - Forest Nurseries and Gathering of Forest Products
# 103 of 2328 - 11321 - Forest Nurseries and Gathering of Forest Products
# 104 of 2328 - 113210 - Forest Nurseries and Gathering of Forest Products
# 105 of 2328 - 1133 - Logging
# 106 of 2328 - 11331 - Logging
# 107 of 2328 - 113310 - Logging
# 108 of 2328 - 114 - Fishing, Hunting and Trapping
# 109 of 2328 - 1141 - Fishing
# 110 of 2328 - 11411 - Fishing
# 111 of 2328 - 114111 - Finfish Fishing
# 112 of 2328 - 114112 - Shellfish Fishing
# 113 of 2328 - 114119 - Other Marine Fishing
# 114 of 2328 - 1142 - Hunting and Trapping
# 115 of 2328 - 11421 - Hunting and Trapping
# 116 of 2328 - 114210 - Hunting and Trapping
# 117 of 2328 - 115 - Support Activities for Agriculture and Forestry
# 118 of 2328 - 1151 - Support Activities for Crop Production
# 119 of 2328 - 11511 - Support Activities for Crop Production
# 120 of 2328 - 115111 - Cotton Ginning
# 121 of 2328 - 115112 - Soil Preparation, Planting, and Cultivating
# 122 of 2328 - 115113 - Crop Harvesting, Primarily by Machine
# 123 of 2328 - 115114 - Postharvest Crop Activities (except Cotton Ginning)
# 124 of 2328 - 115115 - Farm Labor Contractors and Crew Leaders
# 125 of 2328 - 115116 - Farm Management Services
# 126 of 2328 - 1152 - Support Activities for Animal Production
# 127 of 2328 - 11521 - Support Activities for Animal Production
# 128 of 2328 - 115210 - Support Activities for Animal Production
# 129 of 2328 - 1153 - Support Activities for Forestry
# 130 of 2328 - 11531 - Support Activities for Forestry
# 131 of 2328 - 115310 - Support Activities for Forestry
# 132 of 2328 - 21 - Mining, Quarrying, and Oil and Gas Extraction
# 133 of 2328 - 211 - Oil and Gas Extraction
# 134 of 2328 - 2111 - Oil and Gas Extraction
# 135 of 2328 - 21111 - Oil and Gas Extraction
# 136 of 2328 - 211111 - Crude Petroleum and Natural Gas Extraction
# 137 of 2328 - 211112 - Natural Gas Liquid Extraction
# 138 of 2328 - 212 - Mining (except Oil and Gas)
# 139 of 2328 - 2121 - Coal Mining
# 140 of 2328 - 21211 - Coal Mining
# 141 of 2328 - 212111 - Bituminous Coal and Lignite Surface Mining
# 142 of 2328 - 212112 - Bituminous Coal Underground Mining
# 143
